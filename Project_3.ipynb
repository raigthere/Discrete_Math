# %% [markdown]
# <a href="https://colab.research.google.com/github/raigthere/Discrete_Math/blob/master/Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part #3 : CPSMA 3133 Dr. Jacob
#
#
# > Discrete Mathematics
#
#
# >  Topic: Structures and Numbers
#
#
#
#
#
#
#
# $$Presented by: Gulsan Rai$$

# %% [markdown]
# ##1) Graphs & Trees

# %% [markdown]
# > (**a**)Here, I am constructing a graph that helps me to reach the neighborhood Walmart from my home. One the way, there are some streets/paths that I need to follow to reach my destination. It resembles the structure having exactly at least 5 vertices and 5 edges.

# %% [markdown]
# > (**b**) Following the story, I have presented the visualization of the structure using **graphviz** package.

# %%
import graphviz

dot = graphviz.Digraph(comment='RouteToWalmart')
dot.edge('Home Sweet Home', '7Eleven', label= 'Beltline Road')
dot.edge('7Eleven', 'Kurry Palace','Country Club')
dot.edge('Kurry Palace', 'Army','Lincoln St.')
dot.edge('Army', 'Austin Cafe','William Dehaes Dr.')
dot.edge('Austin Cafe', 'Walmart','Esters Rd.')

dot.edge('Home Sweet Home','Walmart',constraint ='true')
dot.edge('Home Sweet Home','Kurry Palace',constraint ='true')
dot

# %% [markdown]
# >(**c**) A path in the graph is the sequence where vertices is visited once.
#
# >>For my given structure, the path is
# $$
# HomeSweetHome-7eleven-KurryPalace-Army-AustinCafe-Walmart
# $$

# %% [markdown]
# >(**d**)The degree of a vertex is the number of edges connecting it.
#
# For my given structure, the degree of a vertices is
# $$
# HomeSweetHome=3
# $$
#
# $$
# 7eleven=2
# $$
#
# $$
# KurryPalace=3
# $$
#
# $$
# Army=2
# $$
#
# $$
# Austin Cafe=2
# $$
#
# $$
# Walmart=2
# $$

# %% [markdown]
# >(**e**) A cycle is a closed path. If we see the structure, we can find the cycle exists. It is determined by: $$𝐻𝑜𝑚𝑒𝑆𝑤𝑒𝑒𝑡𝐻𝑜𝑚𝑒−7𝑒𝑙𝑒𝑣𝑒𝑛−𝐾𝑢𝑟𝑟𝑦𝑃𝑎𝑙𝑎𝑐𝑒−𝐴𝑟𝑚𝑦−𝐴𝑢𝑠𝑡𝑖𝑛𝐶𝑎𝑓𝑒−𝑊𝑎𝑙𝑚𝑎𝑟𝑡-𝐻𝑜𝑚𝑒𝑆𝑤𝑒𝑒𝑡𝐻𝑜𝑚𝑒$$

# %% [markdown]
# ## 2) Numbers

# %% [markdown]
#  > (**a**)In this section, the task is to convert the given number which is in base 7 into base 10, also known as decimal. For the specific task, here we will have addition of multiplication of digit with its base number i.e. 7 to the power of the number of remaining digits in the number. Now, let's convert 24036(base 7) into decimal.
# It can be shown in the following code:

# %%
2*7**4+4*7**3+0*7**2+3*7**1+6*7**0
# Out:
# 6201

# %% [markdown]
# >> As a result, the conversion of 24036 in base 7 into decimal would be
# $$
# 6201
# $$
#  It is a simple form of conversion. Now let's put some spice in doing next given task.

# %% [markdown]
# >(**b**) Now, here I am going to run through the mathematics of converting a hexadecimal number into decimal.For that purpose, I'll use same tricks from above question but we need to know
#
# $$
# a=10
# $$
#
# $$
# b=11
# $$
#
# $$
# c=12
# $$
#
# $$
# d=13
# $$
#
# $$
# e=14
# $$
#
# $$
# f=15.
# $$
# Thence, let's convert the hexadecimal number 72e3 or 0x72e3 into base ten.

# %%
7*16**3+2*16**2+14*16**1+3*16**0
# Out:
# 29411

# %% [markdown]
# >>After conversion, our asnwer output in decimal would be
#
# $$
# 29411
# $$

# %% [markdown]
# >>It can also be tested in another way by following way. `int` will take the hex back to decimal.

# %%
int('72e3',16)
# Out:
# 29411

# %% [markdown]
# >(**c**) Now, let's convert 3735928559 into hexadecimal.For this purpose, I will run through the mathematics of converting a decimal number into hex just to show the actions required.  I'll use the `math.floor` function to get the whole divisor and `%` to get the remainder.

# %%
from math import floor
print(3735928559 %16)
floor(3735928559 /16)
# Out:
# 15
# 233495534

# %%
print(233495534%16)
floor(233495534/16)
# Out:
# 14
# 14593470

# %%
print(14593470%16)
floor(14593470/16)
# Out:
# 14
# 912091

# %%
print(912091%16)
floor(912091/16)
# Out:
# 11
# 57005

# %%
print(57005%16)
floor(57005/16)
# Out:
# 13
# 3562

# %%
print(3562%16)
floor(3562/16)
# Out:
# 10
# 222

# %%
print(222%16)
floor(222/16)
# Out:
# 14
# 13

# %%
print(13%16)
floor(13/16)
# Out:
# 13
# 0

# %% [markdown]
# >> Remainder digits from bottom to top calculation will be our answer.

# %% [markdown]
# >>Now, via applying the unique letter-number scheme, our answer will turn out to be
# $$
# deadbeef
# $$

# %% [markdown]
# >>There is a provision we can examine with the built-in way. Let's check if our answer is true. Also, if '0x' appears, it will tell us that's a hexadecimal number.

# %%
hex(3735928559)
# Out:
# '0xdeadbeef'

# %% [markdown]
# >(**d**) Inorder to get 2's complement of binary number, we need to find 1's complement of given number and then, add 1 to the least significant bit. Now, let's preform the base ten subtraction 25 − 37.

# %%
25-37
# Out:
# -12

# %% [markdown]
# >> The binary number for 12 is
#
# $$
# 0000 1100
# $$

# %% [markdown]
# >> The binary number for -12 would be
#
# $$
# 1111 0011
# $$

# %% [markdown]
# >>Adding +1 in the end-digit would turn over the binary number into Two's complement. **i.e.**
#
# $$
# 1111 0100
# $$

# %% [markdown]
# ###So, why do binary and hexadecimal are important to computers in modern era?
#
# Talking about computers, it uses binary numbering system for computations and overall operations. It has been like that, however, hexadecimal numbering system is often used by programmers to simplify the binary numbering system. In addition, it allows more human-friendly representation and express value in a single hexadecimal digit rather than 4 binary bits. Basically, it's used for efficient-effective operation and minimum storage of data manipulation.
